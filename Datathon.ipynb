# %%
import pandas as pd

# Reading CSV
df = pd.read_csv('FY2023_068_Contracts_Full_20240214_1.csv')
# Out:
#                     contract_transaction_unique_key  \
# 0         6800_-NONE-_68HE0B21P0185_P00007_-NONE-_0
# 1         6800_-NONE-_68HE0B21P0185_P00006_-NONE-_0
# 2                  6800_6800_0005_P00020_EPC18008_0
# 3                  6800_6800_0005_P00024_EPC18008_0
# 4                  6800_6800_0005_P00022_EPC18008_0
# ..                                              ...
# 399  6800_6800_68HE0721F0122_P00002_68HE0720D0005_0
# 400  6800_6800_68HE0721F0143_P00003_68HE0318D0003_0
# 401       6800_-NONE-_68HE0522P0005_P00002_-NONE-_0
# 402                6800_6800_0041_P00031_EPW17011_0
# 403                6800_6800_0041_P00032_EPW17011_0
#
#                           contract_award_unique_key  award_id_piid  \
# 0         CONT_AWD_68HE0B21P0185_6800_-NONE-_-NONE-  68HE0B21P0185
# 1         CONT_AWD_68HE0B21P0185_6800_-NONE-_-NONE-  68HE0B21P0185
# 2                  CONT_AWD_0005_6800_EPC18008_6800           0005
# ...

# %%
# Columns
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a4973e9a54e8> in <cell line: 2>()
#       1 # Columns
# ----> 2 df.columns
#
# NameError: name 'df' is not defined
