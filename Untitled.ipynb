# %%
import pandas as pd

df_2024 = pd.read_csv('FY2024.csv')
df_all = pd.read_csv('FYAll.csv', low_memory = False)

df_2024.info()
df_all.info()

df_2024.head()
df_all.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3742 entries, 0 to 3741
# Columns: 297 entries, contract_transaction_unique_key to last_modified_date
# dtypes: float64(40), int64(5), object(252)
# memory usage: 8.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29449 entries, 0 to 29448
# Columns: 299 entries, correction_delete_ind to last_modified_date
# dtypes: float64(37), int64(4), object(258)
# memory usage: 67.2+ MB
#    correction_delete_ind  agency_id  \
# 0                    NaN       6800
# 1                    NaN       6800
# 2                    NaN       6800
# 3                    NaN       6800
# 4                    NaN       6800
#
#                contract_transaction_unique_key  \
# 0    6800_3600_68HE0123F0054_0_36F79723D0002_0
# 1       6800_3600_68HE0B23F0070_0_V797D60613_0
# 2       6800_3600_68HERC22F0304_0_V797P2217D_0
# 3  6800_3600_68HERC22F0304_P00001_V797P2217D_0
# 4  6800_3600_68HERC22F0304_P00002_V797P2217D_0
#
# ...
